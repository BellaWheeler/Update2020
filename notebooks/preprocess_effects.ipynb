# %%
import numpy as np
import pandas as pd
import os

# %%
os.chdir('..')

# %%
data = pd.read_excel('data/nasu1719pr.xlsx',sheet_name='Effects',header=5)
data = data.iloc[:,1:]
data.tail()
# Out:
#                                                Product  \
# 100  Sports services and amusement and recreation s...
# 101  Services furnished by membership organisations...
# 102  Repair services of computers and personal and ...
# 103               Other personal services
# 104  Services of households as employers of domesti...
#
#      Intermediate consumption at basic prices  Use of imported products, cif  \
# 100                                  0.538777                       0.095125
# 101                                  0.630764                       0.107432
# 102                                  0.461123                       0.119809
# 103                                  0.291347                       0.045914
# 104                                  0.000000                       0.000000
#
#      Taxes less subsidies on products  \
# 100                          0.044333
# 101                          0.018442
# 102                          0.005618
# 103                          0.025488
# 104                          0.000000
#
#      Intermediate consumption at purchaser's prices  \
# 100                                        0.678234
# 101                                        0.756638
# 102                                        0.586549
# 103                                        0.362749
# 104                                        0.000000
#
#      Compensation of employees  Gross operating surplus and mixed income  \
# 100                   0.547284                                  0.288025
# 101                   0.656669                                  0.206858
# 102                   0.474780                                  0.388797
# 103                   0.312140                                  0.605178
# 104                   1.000000                                  0.000000
#
#      Taxes less subsidies on production  Gross value added    Output
# 100                            0.025234           0.860542  1.538777
# 101                            0.010598           0.874126  1.630764
# 102                            0.010996           0.874574  1.461123
# 103                            0.011280           0.928598  1.291347
# 104                            0.000000           1.000000  1.000000

# %%
cpa = pd.read_excel('data/nasu1719pr.xlsx',sheet_name='Use BP PxI',header=4)
cpa = pd.DataFrame(cpa.iloc[1:106,0])
cpa = cpa.rename(columns={cpa.columns[0]: 'CPA'})
cpa = cpa.reset_index()
cpa
# Out:
#      index            CPA
# 0        1        CPA_A01
# 1        2        CPA_A02
# 2        3        CPA_A03
# 3        4        CPA_B05
# 4        5  CPA_B06 & B07
# ..     ...            ...
# 100    101        CPA_R93
# 101    102        CPA_S94
# 102    103        CPA_S95
# 103    104        CPA_S96
# 104    105        CPA_T97
#
# [105 rows x 2 columns]

# %%
data
# Out:
#                                                Product  \
# 0    Products of agriculture, hunting and related s...
# 1    Products of forestry, logging and related serv...
# 2    Fish and other fishing products; aquaculture p...
# 3                        Coal and lignite
# 4    Extraction Of Crude Petroleum And Natural Gas ...
# ..                                                 ...
# 100  Sports services and amusement and recreation s...
# 101  Services furnished by membership organisations...
# 102  Repair services of computers and personal and ...
# 103               Other personal services
# 104  Services of households as employers of domesti...
#
#      Intermediate consumption at basic prices  Use of imported products, cif  \
# 0                                    1.034810                       0.143116
# 1                                    0.801151                       0.102938
# 2                                    0.880631                       0.247649
# 3                                    0.875459                       0.142402
# 4                                    0.581088                       0.112951
# ..                                        ...                            ...
# 100                                  0.538777                       0.095125
# 101                                  0.630764                       0.107432
# 102                                  0.461123                       0.119809
# 103                                  0.291347                       0.045914
# 104                                  0.000000                       0.000000
#
#      Taxes less subsidies on products  \
# 0                            0.029370
# 1                            0.017780
# 2                            0.023940
# 3                            0.022121
# 4                            0.010639
# ..                                ...
# 100                          0.044333
# 101                          0.018442
# 102                          0.005618
# 103                          0.025488
# 104                          0.000000
#
#      Intermediate consumption at purchaser's prices  \
# 0                                          1.207295
# 1                                          0.921869
# 2                                          1.152221
# 3                                          1.039981
# 4                                          0.704677
# ..                                              ...
# 100                                        0.678234
# 101                                        0.756638
# 102                                        0.586549
# 103                                        0.362749
# 104                                        0.000000
#
#      Compensation of employees  Gross operating surplus and mixed income  \
# 0                     0.364815                                  0.534229
# 1                     0.483787                                  0.391069
# 2                     0.397328                                  0.323792
# 3                     0.462668                                  0.397986
# 4                     0.237086                                  0.630092
# ..                         ...                                       ...
# 100                   0.547284                                  0.288025
# 101                   0.656669                                  0.206858
# 102                   0.474780                                  0.388797
# 103                   0.312140                                  0.605178
# 104                   1.000000                                  0.000000
#
#      Taxes less subsidies on production  Gross value added    Output
# 0                             -0.071529           0.827515  2.034810
# 1                              0.004425           0.879282  1.801151
# 2                              0.007290           0.728411  1.880631
# 3                             -0.025176           0.835478  1.875459
# 4                              0.009232           0.876411  1.581088
# ..                                  ...                ...       ...
# 100                            0.025234           0.860542  1.538777
# 101                            0.010598           0.874126  1.630764
# 102                            0.010996           0.874574  1.461123
# 103                            0.011280           0.928598  1.291347
# 104                            0.000000           1.000000  1.000000
#
# [105 rows x 10 columns]

# %%
data['Product'] = cpa['CPA'].astype(str).str.cat(data['Product'].astype(str), sep=' ')
data['Product'] = data['Product'].apply(lambda x: str(x)[4:])
data
# Out:
#                                                Product  \
# 0    A01 Products of agriculture, hunting and relat...
# 1    A02 Products of forestry, logging and related ...
# 2    A03 Fish and other fishing products; aquacultu...
# 3                    B05 Coal and lignite
# 4    B06 & B07 Extraction Of Crude Petroleum And Na...
# ..                                                 ...
# 100  R93 Sports services and amusement and recreati...
# 101  S94 Services furnished by membership organisat...
# 102  S95 Repair services of computers and personal ...
# 103           S96 Other personal services
# 104  T97 Services of households as employers of dom...
#
#      Intermediate consumption at basic prices  Use of imported products, cif  \
# 0                                    1.034810                       0.143116
# 1                                    0.801151                       0.102938
# 2                                    0.880631                       0.247649
# 3                                    0.875459                       0.142402
# 4                                    0.581088                       0.112951
# ..                                        ...                            ...
# 100                                  0.538777                       0.095125
# 101                                  0.630764                       0.107432
# 102                                  0.461123                       0.119809
# 103                                  0.291347                       0.045914
# 104                                  0.000000                       0.000000
#
#      Taxes less subsidies on products  \
# 0                            0.029370
# 1                            0.017780
# 2                            0.023940
# 3                            0.022121
# 4                            0.010639
# ..                                ...
# 100                          0.044333
# 101                          0.018442
# 102                          0.005618
# 103                          0.025488
# 104                          0.000000
#
#      Intermediate consumption at purchaser's prices  \
# 0                                          1.207295
# 1                                          0.921869
# 2                                          1.152221
# 3                                          1.039981
# 4                                          0.704677
# ..                                              ...
# 100                                        0.678234
# 101                                        0.756638
# 102                                        0.586549
# 103                                        0.362749
# 104                                        0.000000
#
#      Compensation of employees  Gross operating surplus and mixed income  \
# 0                     0.364815                                  0.534229
# 1                     0.483787                                  0.391069
# 2                     0.397328                                  0.323792
# 3                     0.462668                                  0.397986
# 4                     0.237086                                  0.630092
# ..                         ...                                       ...
# 100                   0.547284                                  0.288025
# 101                   0.656669                                  0.206858
# 102                   0.474780                                  0.388797
# 103                   0.312140                                  0.605178
# 104                   1.000000                                  0.000000
#
#      Taxes less subsidies on production  Gross value added    Output
# 0                             -0.071529           0.827515  2.034810
# 1                              0.004425           0.879282  1.801151
# 2                              0.007290           0.728411  1.880631
# 3                             -0.025176           0.835478  1.875459
# 4                              0.009232           0.876411  1.581088
# ..                                  ...                ...       ...
# 100                            0.025234           0.860542  1.538777
# 101                            0.010598           0.874126  1.630764
# 102                            0.010996           0.874574  1.461123
# 103                            0.011280           0.928598  1.291347
# 104                            0.000000           1.000000  1.000000
#
# [105 rows x 10 columns]

# %%
# convert wide table to long table
effects = pd.melt(data, 
                     id_vars='Product', 
                     value_vars=data.columns.to_list()[1:]).dropna()

effects.shape
# Out:
# (945, 3)

# %%
effects.head()
# Out:
#                                              Product  \
# 0  A01 Products of agriculture, hunting and relat...
# 1  A02 Products of forestry, logging and related ...
# 2  A03 Fish and other fishing products; aquacultu...
# 3                  B05 Coal and lignite
# 4  B06 & B07 Extraction Of Crude Petroleum And Na...
#
#                                    variable     value
# 0  Intermediate consumption at basic prices  1.034810
# 1  Intermediate consumption at basic prices  0.801151
# 2  Intermediate consumption at basic prices  0.880631
# 3  Intermediate consumption at basic prices  0.875459
# 4  Intermediate consumption at basic prices  0.581088

# %%
# Strip whitespace from start and finish

def space_stripper(x):
    return x.strip()

effects[['Product','variable']] = effects[['Product','variable']].applymap(lambda x: space_stripper(x))
# Out:
# /tmp/ipykernel_12744/616538641.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   effects[['Product','variable']] = effects[['Product','variable']].applymap(lambda x: space_stripper(x))

# %%
effects['value'] = effects['value'].astype(float)
effects.head()
# Out:
#                                              Product  \
# 0  A01 Products of agriculture, hunting and relat...
# 1  A02 Products of forestry, logging and related ...
# 2  A03 Fish and other fishing products; aquacultu...
# 3                               B05 Coal and lignite
# 4  B06 & B07 Extraction Of Crude Petroleum And Na...
#
#                                    variable     value
# 0  Intermediate consumption at basic prices  1.034810
# 1  Intermediate consumption at basic prices  0.801151
# 2  Intermediate consumption at basic prices  0.880631
# 3  Intermediate consumption at basic prices  0.875459
# 4  Intermediate consumption at basic prices  0.581088

# %%
effects['factor'] = 'total impact'
effects.head()
# Out:
#                                              Product  \
# 0  A01 Products of agriculture, hunting and relat...
# 1  A02 Products of forestry, logging and related ...
# 2  A03 Fish and other fishing products; aquacultu...
# 3                               B05 Coal and lignite
# 4  B06 & B07 Extraction Of Crude Petroleum And Na...
#
#                                    variable     value        factor
# 0  Intermediate consumption at basic prices  1.034810  total impact
# 1  Intermediate consumption at basic prices  0.801151  total impact
# 2  Intermediate consumption at basic prices  0.880631  total impact
# 3  Intermediate consumption at basic prices  0.875459  total impact
# 4  Intermediate consumption at basic prices  0.581088  total impact

# %%
effects.to_csv('data/detailed_effects.csv')
